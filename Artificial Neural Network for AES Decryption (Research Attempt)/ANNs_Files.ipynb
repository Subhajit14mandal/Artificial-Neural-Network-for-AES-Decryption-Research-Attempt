# %%
# !pip install pycryptodome
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 24.2 MB/s eta 0:00:00
# ...

# %%
import pandas as pd
from Crypto.Cipher import AES
from Crypto.Util.Padding import pad, unpad
from Crypto.Random import get_random_bytes

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
data=pd.read_fwf('/content/drive/MyDrive/ANNs/TwitterLowerAsciiCorpus.txt')
data.head()
# Out:
#   what's up dadyo when did you get back on twitter? haha
# 0  like 2 weeks ago and it's going as terribly as...
# 1       literally never about that account, love it.
# 2  answer me this fellow apple peoples: how many ...
# 3           about 50 times today. terminal vim user.
# 4  seems the major complaints so far are from vim...

# %%
data.tail()
# Out:
#       what's up dadyo when did you get back on twitter? haha
# 10508                                        suck on him
# 10509                                                lol
# 10510  chiefs and fans piss me off like you only have...
# 10511  chiefs and fans piss me off like you only have...
# 10512        i wouldn't know i'm not a sports fan at all

# %%
data=data.rename(columns={"what's up dadyo when did you get back on twitter? haha": "Plain_text"})

# %%
data.head()
# Out:
#                                           Plain_text
# 0  like 2 weeks ago and it's going as terribly as...
# 1       literally never about that account, love it.
# 2  answer me this fellow apple peoples: how many ...
# 3           about 50 times today. terminal vim user.
# 4  seems the major complaints so far are from vim...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10513 entries, 0 to 10512
# Data columns (total 1 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Plain_text  10513 non-null  object
# dtypes: object(1)
# memory usage: 82.3+ KB

# %%
data.isnull().sum()
# Out:
# Plain_text    0
# dtype: int64

# %%
data['Key']=""

# %%
data['Key']=data['Key'].apply(lambda x: get_random_bytes(16))

# %%
data.head()
# Out:
#                                           Plain_text  \
# 0  like 2 weeks ago and it's going as terribly as...
# 1       literally never about that account, love it.
# 2  answer me this fellow apple peoples: how many ...
# 3           about 50 times today. terminal vim user.
# 4  seems the major complaints so far are from vim...
#
#                                                  Key
# 0  b'\xda\x7f\xe9\xdf\x1fvz\xfb\xcd\xf2ty\x9b\xa7...
# 1     b'q\x98\xc7\xeaw\x1f>\x90\xc5\xbajZ]\xb9l\xd6'
# 2           b'b\xbdO~\xb9Z.RE\xfa\xf3\xb7q\xbc\x91R'
# 3  b'-\xec\x07t\x1c\xff\x92L\x19\xefNO\x97\xc9-\x14'
# 4  b'!\xcf\x0b\xfb2\rv\xc4\xf1m\x18\xfa\xcaC\x96\...

# %%
def encoding(row):
    x=row[0]
    # Convert the string to bytes
    str_x=x.encode('utf-8')
    # Generate a random 16-byte AES key (for AES-128)
    key = row[1]

    # Generate a random initialization vector (IV)
    # iv = get_random_bytes(16)

    # Create AES cipher object in CBC mode
    cipher = AES.new(key, AES.MODE_CBC)

    # Pad the data to be a multiple of 16 bytes
    padded_data = pad(str_x, AES.block_size)

    # Encrypt the padded data
    ciphertext = cipher.encrypt(padded_data)

    return ciphertext.hex()

# %%
data["Cipher_text"]=data[["Plain_text","Key"]].apply(encoding,axis=1)
# Out:
# <ipython-input-17-6d850151eb68>:2: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   x=row[0]
# <ipython-input-17-6d850151eb68>:6: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   key = row[1]

# %%
data.head()
# Out:
#                                           Plain_text  \
# 0  like 2 weeks ago and it's going as terribly as...
# 1       literally never about that account, love it.
# 2  answer me this fellow apple peoples: how many ...
# 3           about 50 times today. terminal vim user.
# 4  seems the major complaints so far are from vim...
#
#                                                  Key  \
# 0  b'\xda\x7f\xe9\xdf\x1fvz\xfb\xcd\xf2ty\x9b\xa7...
# 1     b'q\x98\xc7\xeaw\x1f>\x90\xc5\xbajZ]\xb9l\xd6'
# 2           b'b\xbdO~\xb9Z.RE\xfa\xf3\xb7q\xbc\x91R'
# 3  b'-\xec\x07t\x1c\xff\x92L\x19\xefNO\x97\xc9-\x14'
# 4  b'!\xcf\x0b\xfb2\rv\xc4\xf1m\x18\xfa\xcaC\x96\...
#
#                                          Cipher_text
# 0  625d195f17e84a160e51e4c96b4796f63456f14e46b976...
# 1  d9e3479b9ded8368d1779d06d9b9e0a503e1d9a21ae409...
# 2  2e4deec4907057d1cd705fb8b1fb8b37325e551fca1bb2...
# 3  4f87a78c20c1e444b4d9063a4d29516ce16bfed6aaaea8...
# 4  ee308cb97bf28a076735149bde3342639db98ca1d42177...

# %%
data.to_csv('/content/drive/MyDrive/ANNs/ANNs_file_2.csv',index=False)

# %%
s='subhajit mandal'
s.encode('utf=8')
# Out:
# b'subhajit mandal'

# %%
len(s)
# Out:
# 15

# %%
a=b'\r\xdc\xd0\xde\x04o\xeb,\xdb\n\xb3\n\x0e\xa52\x0c'
len(a)
# Out:
# 16

# %%
a=b'98c466988f0d9f9ed1383cb9bb9d553e'
len(a)
# Out:
# 32
